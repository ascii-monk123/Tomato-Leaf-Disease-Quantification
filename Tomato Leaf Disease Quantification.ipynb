# %% [markdown]
# <h1> Quantification of tomato leaf diseases</h1>

# %% [markdown]
# <p>In tomato early blight infection </h1>

# %%
# %pip install opencv-python
# Out:
# ...
#      |████████████████████████████████| 50.4 MB 73 kB/s s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#importing libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os.path

# %%
rootFolder='/home/aahan/Documents/Minor Project/Tomato Early Blight Segmented'
def readImage(imageName):
    return cv2.imread('{}/{}'.format(rootFolder,imageName))
tomatoLeaf=readImage('01861c93-ea8b-4820-aaa8-cc6003b3e75b___RS_Erly.B 7855_final_masked.jpg')
#converting image to grayscale
tomatoLeaf=cv2.cvtColor(tomatoLeaf,cv2.COLOR_BGR2GRAY)
#showing the initial image
plt.imshow(tomatoLeaf,cmap="gray")
